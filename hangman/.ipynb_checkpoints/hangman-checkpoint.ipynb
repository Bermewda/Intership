# %%
import csv
import numpy as np 
import random

def game(fname):
    r = []
    score=0
    with open(fname,'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)   
        r = [row for row in reader]
    csvfile.close()
#     print(np.array(r))
    random.shuffle(r)
#     print(np.array(r))

    for i in r:
        guess=10
        print("\n")
        print("hint : "+i[1])
        
        word=[]
        for j in i[0]:
            if j in "1234567890-+!@#$%^&*()~ ":
                word.append(j)
            else:
                word.append("_")
            
            
        while guess > 0 and '_' in word:
            print(str(word) + " remaining wrong guess "+str(guess))  
            
            ans = input()
            start=0
            if ans.lower() in word :
                guess-=1;
                print("you used to guess it : "+ans.lower())                
            elif ans.lower() in i[0] :    
                for k in i[0]:
                    if ans.lower() in k : 
                        word[i[0].find(ans.lower(),start)]=ans.lower()
                        start=i[0].find(ans.lower(),start)+1
#                         print(start)
               
            else : 
                guess-=1;
                print("wrong guessed : "+ans.lower())
                
        print(str(word) + " remaining wrong guess "+str(guess)) 
        print("Answer : "+i[0])
        if guess != 0:
            score+=1

    print("\n")
    print("You score : "+str(score))
    
    

print("Select Category:")
print("kpop brands (1)")
print("hit songs (2)\n")
category = input() 

if category == '1' :
    game('kpop.csv')
    
elif category == '2' :
    game('song.csv')
else:
    print("error!! don't have category")
# Out:
# Select Category:
# kpop brands (1)
# hit songs (2)
#
# 1
#
#
# hint : Used to be called Beast.
# ['_', '_', '_', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# h
# 1
# 4
# 8
# ['h', '_', '_', 'h', '_', '_', '_', 'h', '_'] remaining wrong guess 10
# i
# 2
# 6
# ['h', 'i', '_', 'h', '_', 'i', '_', 'h', '_'] remaining wrong guess 10
# g
# 3
# 7
# ['h', 'i', 'g', 'h', '_', 'i', 'g', 'h', '_'] remaining wrong guess 10
# t
# 9
# ['h', 'i', 'g', 'h', '_', 'i', 'g', 'h', 't'] remaining wrong guess 10
# l
# 5
# ['h', 'i', 'g', 'h', 'l', 'i', 'g', 'h', 't'] remaining wrong guess 10
# Answer : highlight
#
#
# hint : The name of the fanclub is Sone.
# ['_', '_', '_', '_', ' ', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# g
# 1
# 6
# ['g', '_', '_', '_', ' ', 'g', '_', '_', '_', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# e
# 7
# 9
# ['g', '_', '_', '_', ' ', 'g', 'e', '_', 'e', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# r
# 3
# 10
# ['g', '_', 'r', '_', ' ', 'g', 'e', '_', 'e', 'r', '_', '_', '_', '_', '_'] remaining wrong guess 10
# a
# 11
# ['g', '_', 'r', '_', ' ', 'g', 'e', '_', 'e', 'r', 'a', '_', '_', '_', '_'] remaining wrong guess 10
# n
# 8
# 15
# ['g', '_', 'r', '_', ' ', 'g', 'e', 'n', 'e', 'r', 'a', '_', '_', '_', 'n'] remaining wrong guess 10
# t
# 12
# ['g', '_', 'r', '_', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', '_', '_', 'n'] remaining wrong guess 10
# i
# 2
# 13
# ['g', 'i', 'r', '_', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'i', '_', 'n'] remaining wrong guess 10
# o
# 14
# ['g', 'i', 'r', '_', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'i', 'o', 'n'] remaining wrong guess 10
# l
# 4
# ['g', 'i', 'r', 'l', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'i', 'o', 'n'] remaining wrong guess 10
# Answer : girl generation
#
#
# hint : In the group, there are three foreign members.
# ['_', '_', '_', '7'] remaining wrong guess 10
# g
# 1
# ['g', '_', '_', '7'] remaining wrong guess 10
# o
# 2
# ['g', 'o', '_', '7'] remaining wrong guess 10
# t
# 3
# ['g', 'o', 't', '7'] remaining wrong guess 10
# Answer : got7
#
#
# hint : The name of the band is two colors.
# ['_', '_', '_', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# b
# 1
# ['b', '_', '_', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# l
# 2
# ['b', 'l', '_', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# a
# 3
# ['b', 'l', 'a', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# c
# 4
# ['b', 'l', 'a', 'c', '_', '_', '_', '_', '_'] remaining wrong guess 10
# k
# 5
# 9
# ['b', 'l', 'a', 'c', 'k', '_', '_', '_', 'k'] remaining wrong guess 10
# p
# 6
# ['b', 'l', 'a', 'c', 'k', 'p', '_', '_', 'k'] remaining wrong guess 10
# i
# 7
# ['b', 'l', 'a', 'c', 'k', 'p', 'i', '_', 'k'] remaining wrong guess 10
# n
# 8
# ['b', 'l', 'a', 'c', 'k', 'p', 'i', 'n', 'k'] remaining wrong guess 10
# Answer : blackpink
#
#
# hint : One of the members had joined We Got Married(reality variety show) with yook sungjae from btob.
# ['_', '_', '_', ' ', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# r
# 1
# ['r', '_', '_', ' ', '_', '_', '_', '_', '_', '_'] remaining wrong guess 10
# e
# 2
# 6
# 9
# ['r', 'e', '_', ' ', '_', 'e', '_', '_', 'e', '_'] remaining wrong guess 10
# d
# 3
# ['r', 'e', 'd', ' ', '_', 'e', '_', '_', 'e', '_'] remaining wrong guess 10
# v
# 5
# 8
# ['r', 'e', 'd', ' ', 'v', 'e', '_', 'v', 'e', '_'] remaining wrong guess 10
# l
# 7
# ['r', 'e', 'd', ' ', 'v', 'e', 'l', 'v', 'e', '_'] remaining wrong guess 10
# t
# 10
# ['r', 'e', 'd', ' ', 'v', 'e', 'l', 'v', 'e', 't'] remaining wrong guess 10
# Answer : red velvet
#
#
# You score : 5
